# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

# %%
# prompt: Create a scatterplot that contains the points  (−6,90),(−5,41.67),(−4,20),(−3,9),(−2,3.33),(−1,0.71),(0,0),(1,0.56),(2,2),(3,4.09),(4,6.67),(8,20) .

x = [-6, -5, -4, -3, -2, -1, 0, 1, 2, 3, 4, 8]
y = [90, 41.67, 20, 9, 3.33, 0.71, 0, 0.56, 2, 4.09, 6.67, 20]

plt.scatter(x, y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Scatter Plot")
plt.grid(True)
plt.show()

# %%
#Enter your answer here
x = np.linspace(-6, 8, 100)
y = (5 * x**2) / (x + 8)

plt.plot(x, y)
plt.xlabel("X-axis")
# Out:
# Text(0.5, 0, 'X-axis')
