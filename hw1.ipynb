# %%
import numpy as np 
print(np.__version__)
import sys
print(sys.executable)
import matplotlib as plt
# Out:
# 2.2.4
# /opt/miniconda3/envs/rag/bin/python

# %%
np.exp(2)
# Out:
# np.float64(7.38905609893065)

# %%
def sigmoid(z):
  return 1/(1+np.exp(-z))

# %%
print(sigmoid(2))
# Out:
# 0.8807970779778823

# %%
def sigmoid_prime(z):
  return np.exp(-z)/(1+np.exp(-z))**2

# %%
np.cos(np.pi) - np.sqrt(np.pi+ np.sin(np.pi)+10**2)+245
# Out:
# np.float64(233.84413506127666)

# %%
import random
for i in range(0,1):
    print(random.random())
# Out:
# 0.46849116817930003

# %%
import numpy as np
a= np.array([[1,2,3],[4,5,6]])
np.reshape(a,6)
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
import numpy as np
import matplotlib.pyplot as plt  # Ensure correct import

# Generate a random 28x28 grayscale image
image = np.random.rand(28, 28)

# Display the image
plt.imshow(image, cmap='gray')
plt.title("28x28 Random Grayscale Image")
plt.colorbar()
plt.show()  # Always add this to properly render the image
print(image)
# Out:
# [[3.96184959e-01 9.54705580e-01 4.52759692e-02 6.43623991e-02
#   8.32190205e-01 7.67377430e-01 4.66113144e-01 8.05288396e-01
#   5.99717895e-01 7.23738613e-01 1.27790774e-01 5.87388256e-01
#   4.72492982e-01 7.13244338e-01 6.65090132e-01 6.30770626e-01
#   4.04562588e-01 3.42304486e-01 4.26120309e-01 1.30573473e-02
#   9.23279376e-01 5.97143556e-01 3.86699564e-01 4.64166125e-01
#   5.39304732e-01 2.95638210e-01 3.34189861e-01 4.12433654e-01]
#  [6.97096377e-01 9.95001479e-01 9.84669489e-01 1.82890089e-01
#   3.06932501e-01 5.22396567e-01 7.91933084e-01 1.69612910e-01
#   8.00126130e-02 6.10823402e-01 5.00444423e-01 7.61053427e-01
#   5.64598821e-01 5.61762503e-01 6.91914144e-01 7.46535006e-01
#   3.67021356e-01 1.29861747e-01 6.92564540e-01 8.06993166e-01
#   5.51489734e-01 8.26572938e-01 5.91835368e-01 1.15586702e-01
#   1.04101343e-01 6.65773931e-01 3.89852182e-01 7.15581615e-01]
#  [9.26321436e-01 9.66887824e-01 4.94064575e-01 6.19237954e-02
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create a 28x28 array of random values between 0 and 1
image = np.random.rand(28, 28)

# Display the image
plt.imshow(image, cmap='gray')
plt.title("28x28 Random Grayscale Image")
plt.colorbar()
plt.show()
image=np.reshape(image,784)
print(image)
# Out:
# [0.52580359 0.53667493 0.93398604 0.19478387 0.70026488 0.83747828
#  0.10994169 0.5950975  0.50130711 0.86897089 0.43161874 0.91678135
#  0.98446377 0.38769273 0.4002728  0.20709263 0.27632816 0.77191683
#  0.26619699 0.69600241 0.10637936 0.19063514 0.80609655 0.61990493
#  0.53597792 0.27177024 0.92719912 0.11822459 0.16342537 0.0816036
#  0.56665578 0.44723598 0.78846069 0.91525741 0.36592501 0.24411025
#  0.70478916 0.42326017 0.02319842 0.05605224 0.36253231 0.06109424
#  0.1939236  0.91733967 0.67132308 0.82669105 0.27680175 0.05618419
#  0.82083401 0.75871402 0.94368831 0.94148418 0.44917754 0.51555969
#  0.93556661 0.40046862 0.59270712 0.62775385 0.00499665 0.62850176
#  0.08014656 0.08787824 0.34936149 0.30870308 0.0365065  0.65497932
#  0.65924365 0.15403663 0.69738009 0.50346713 0.90073239 0.49339341
#  0.36471698 0.48501008 0.93304693 0.66403284 0.7749476  0.03758463
#  0.50516366 0.20972474 0.54819624 0.71684827 0.32298384 0.43068058
# ...

# %%
def partial_sum(n):
    total = 0
    for i in range(1, n + 1):
        term = (-1)**(i-1) * i**2 / (i**3 + 1)
        total += term
    return total

# %%
a= partial_sum(1000)
b=partial_sum(10000)
c=partial_sum(100000)
print("Sum of first 1,000 terms:", a)
print("Sum of first 10,000 terms:", b)
print("Sum of first 100,000 terms:", c)
# Out:
# Sum of first 1,000 terms: 0.23906099734111588
# Sum of first 10,000 terms: 0.23951074984074172
# Sum of first 100,000 terms: 0.23955574736574214
